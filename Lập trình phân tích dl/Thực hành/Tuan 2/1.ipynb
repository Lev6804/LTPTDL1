# %%
import pandas as pd

# %%
! pip install pandas
# Out:
# ^C
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.1.0-cp312-cp312-win_amd64.whl.metadata (59 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 3.4 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/11.5 MB 3.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/11.5 MB 3.0 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/11.5 MB 2.6 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/11.5 MB 2.5 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/11.5 MB 2.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.1/11.5 MB 2.1 MB/s eta 0:00:04
# ...

# %%
1 #1 Doc file
df= pd.read_csv('orginal_sales_data_edit.csv')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
# hiển thị 5 dòng đầu 
print("5 dòng đầu")
df.head(5)
# Out:
# 5 dòng đầu
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %%
# hiển thị 5 dòng cuối
print("hiển thị 5 dòng cuối")
df.tail(5)
# Out:
# hiển thị 5 dòng cuối
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 2818  12/2/2004   Shipped       4        12     2004  ...          NaN
# 2819  1/31/2005   Shipped       1         1     2005  ...          NaN
# 2820   3/1/2005  Resolved       1         3     2005  ...          NaN
# 2821  3/28/2005   Shipped       1         3     2005  ...          NaN
# 2822   5/6/2005   On Hold       2         5     2005  ...          NaN
#
#           CITY STATE POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %%
# chuyển kiểu dl
df["YEAR_ID"] = df["YEAR_ID"].astype("int32")
print("Dữ liệu sau khi chuyển")
df.head(2)
# Out:
# 5 dòng đầu
# hiển thị 5 dòng cuối
# Dữ liệu sau khi chuyển
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 0        10107               30      95.70                2  2871.0
# 1        10121               34      81.35                5  2765.9
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2   CITY  \
# 0  2/24/2003  Shipped       1         2     2003  ...          NaN    NYC
# 1   5/7/2003  Shipped       2         5     2003  ...          NaN  Reims
#
#   STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# 0    NY      10022     USA       NaN              Yu             Kwai
# 1   NaN      51100  France      EMEA         Henriot             Paul
#
#   DEALSIZE PAYMENTFULLNAME
# 0    Small         Yu Kwai
# 1    Small    Henriot Paul
#
# [2 rows x 28 columns]

# %%
# Xem chiều dài
print("Chiều dài của df: ", len(df))
# Xem kích thước của dataframe
print("Shape: ",df.shape)
# Xem thông tin của df
print("Thông tin: ",df.info)
# Out:
# Chiều dài của df:  2823
# Shape:  (2823, 28)
# Thông tin:  <bound method DataFrame.info of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
# ...

# %%
df['PRODUCTLINE']
# Out:
# 0       Motorcycles
# 1       Motorcycles
# 2       Motorcycles
# 3       Motorcycles
# 4       Motorcycles
#            ...
# 2818          Ships
# 2819          Ships
# 2820          Ships
# 2821          Ships
# 2822          Ships
# Name: PRODUCTLINE, Length: 2823, dtype: object

# %%
df[['ORDERNUMBER','QUANTITYORDERED','PRICEEACH','PRODUCTLINE']]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  PRODUCTLINE
# 0           10107               30      95.70  Motorcycles
# 1           10121               34      81.35  Motorcycles
# 2           10134               41      94.74  Motorcycles
# 3           10145               45      83.26  Motorcycles
# 4           10159               49     100.00  Motorcycles
# ...           ...              ...        ...          ...
# 2818        10350               20     100.00        Ships
# 2819        10373               29     100.00        Ships
# 2820        10386               43     100.00        Ships
# 2821        10397               34      62.24        Ships
# 2822        10414               47      65.52        Ships
#
# [2823 rows x 4 columns]

# %%
df[['ORDERNUMBER','QUANTITYORDERED','PRICEEACH','PRODUCTLINE']].head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  PRODUCTLINE
# 0        10107               30      95.70  Motorcycles
# 1        10121               34      81.35  Motorcycles
# 2        10134               41      94.74  Motorcycles
# 3        10145               45      83.26  Motorcycles
# 4        10159               49     100.00  Motorcycles

# %%
df[0:5]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# ...

# %%
df[['ORDERNUMBER','QUANTITYORDERED','PRICEEACH','PRODUCTLINE']][:5]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  PRODUCTLINE
# 0        10107               30      95.70  Motorcycles
# 1        10121               34      81.35  Motorcycles
# 2        10134               41      94.74  Motorcycles
# 3        10145               45      83.26  Motorcycles
# 4        10159               49     100.00  Motorcycles

# %%
df.drop_duplicates(inplace= True)
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
df['ADDRESSLINE2'].isna().sum()
# Out:
# 2521

# %%
df['ADDRESSLINE2'].fillna('Unknown',inplace = True)
df['ADDRESSLINE2'].isna().sum()
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
df["QUANTITYORDERED"]
# Out:
# 0       30
# 1       34
# 2       41
# 3       45
# 4       49
#         ..
# 2818    20
# 2819    29
# 2820    43
# 2821    34
# 2822    47
# Name: QUANTITYORDERED, Length: 2823, dtype: int64

# %%
df["QUANTITYORDERED"].values
# Out:
# array([30, 34, 41, ..., 43, 34, 47], dtype=int64)

# %%
df[4:9]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 4  10/10/2003  Shipped       4        10     2003  ...       unknow
# 5  10/28/2003  Shipped       4        10     2003  ...       unknow
# 6  11/11/2003  Shipped       4        11     2003  ...       unknow
# 7  11/18/2003  Shipped       4        11     2003  ...       unknow
# 8   12/1/2003  Shipped       4        12     2003  ...       unknow
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 4  San Francisco    CA        NaN     USA       NaN           Brown
# ...

# %%
df.loc[4:10]
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4         10159               49     100.00               14  5205.27
# 5         10168               36      96.66                1  3479.76
# 6         10180               29      86.13                9  2497.77
# 7         10188               48     100.00                1  5512.32
# 8         10201               22      98.57                2  2168.54
# 9         10211               41     100.00               14  4708.44
# 10        10223               37     100.00                1  3965.66
#
#      ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 4   10/10/2003  Shipped       4        10     2003  ...       unknow
# 5   10/28/2003  Shipped       4        10     2003  ...       unknow
# 6   11/11/2003  Shipped       4        11     2003  ...       unknow
# 7   11/18/2003  Shipped       4        11     2003  ...       unknow
# ...

# %%
df.iloc[4:10]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 4  10/10/2003  Shipped       4        10     2003  ...       unknow
# 5  10/28/2003  Shipped       4        10     2003  ...       unknow
# 6  11/11/2003  Shipped       4        11     2003  ...       unknow
# 7  11/18/2003  Shipped       4        11     2003  ...       unknow
# 8   12/1/2003  Shipped       4        12     2003  ...       unknow
# 9   1/15/2004  Shipped       1         1     2004  ...       unknow
#
# ...

# %%
df.loc[2]
# Out:
# ORDERNUMBER                                 10134
# QUANTITYORDERED                                41
# PRICEEACH                                   94.74
# ORDERLINENUMBER                                 2
# SALES                                     3884.34
# ORDERDATE                                7/1/2003
# STATUS                                    Shipped
# QTR_ID                                          3
# MONTH_ID                                        7
# YEAR_ID                                      2003
# PRODUCTLINE                           Motorcycles
# MSRP                                           95
# PRODUCTCODE                              S10_1678
# CATEGORY                                Furniture
# SUBCATEGORY                               Cabinet
# CUSTOMERNAME                      Lyon Souveniers
# PHONE                            +33 1 46 62 7555
# ADDRESSLINE1        27 rue du Colonel Pierre Avia
# ADDRESSLINE2                               unknow
# ...

# %%
df.loc[4:10,['QUANTITYORDERED','SALES']]
# Out:
#     QUANTITYORDERED    SALES
# 4                49  5205.27
# 5                36  3479.76
# 6                29  2497.77
# 7                48  5512.32
# 8                22  2168.54
# 9                41  4708.44
# 10               37  3965.66

# %%
df.iloc[2:9,4:7]
# Out:
#      SALES   ORDERDATE   STATUS
# 2  3884.34    7/1/2003  Shipped
# 3  3746.70   8/25/2003  Shipped
# 4  5205.27  10/10/2003  Shipped
# 5  3479.76  10/28/2003  Shipped
# 6  2497.77  11/11/2003  Shipped
# 7  5512.32  11/18/2003  Shipped
# 8  2168.54   12/1/2003  Shipped

# %%
df.iloc[2]
# Out:
# ORDERNUMBER                                 10134
# QUANTITYORDERED                                41
# PRICEEACH                                   94.74
# ORDERLINENUMBER                                 2
# SALES                                     3884.34
# ORDERDATE                                7/1/2003
# STATUS                                    Shipped
# QTR_ID                                          3
# MONTH_ID                                        7
# YEAR_ID                                      2003
# PRODUCTLINE                           Motorcycles
# MSRP                                           95
# PRODUCTCODE                              S10_1678
# CATEGORY                                Furniture
# SUBCATEGORY                               Cabinet
# CUSTOMERNAME                      Lyon Souveniers
# PHONE                            +33 1 46 62 7555
# ADDRESSLINE1        27 rue du Colonel Pierre Avia
# ADDRESSLINE2                               unknow
# ...

# %%
df.iloc[:10]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...       unknow
# 1    5/7/2003  Shipped       2         5     2003  ...       unknow
# ...

# %%
df.iloc[:10,4:7]
# Out:
#      SALES   ORDERDATE   STATUS
# 0  2871.00   2/24/2003  Shipped
# 1  2765.90    5/7/2003  Shipped
# 2  3884.34    7/1/2003  Shipped
# 3  3746.70   8/25/2003  Shipped
# 4  5205.27  10/10/2003  Shipped
# 5  3479.76  10/28/2003  Shipped
# 6  2497.77  11/11/2003  Shipped
# 7  5512.32  11/18/2003  Shipped
# 8  2168.54   12/1/2003  Shipped
# 9  4708.44   1/15/2004  Shipped

# %%
df.sort_values(by="SALES", ascending = True)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 2249        10425               11      43.83                6    482.13
# 1287        10407                6      90.19                3    541.14
# 2044        10408               15      36.93                1    553.95
# 1551        10280               20      28.88               12    577.60
# 1818        10419               15      42.67                7    640.05
# ...           ...              ...        ...              ...       ...
# 104         10403               66     100.00                9  11886.60
# 1062        10412               60     100.00                9  11887.80
# 53          10424               50     100.00                6  12001.00
# 744         10322               50     100.00                6  12536.50
# 598         10407               76     100.00                2  14082.80
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
df.sort_values(by=['QUANTITYORDERED','PRICEEACH'], ascending = [True,False])
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 751         10409                6     100.00                2    785.64
# 1287        10407                6      90.19                3    541.14
# 315         10419               10     100.00               11   1092.20
# 907         10423               10      88.14                1    881.40
# 2507        10401               11     100.00                8   1135.31
# ...           ...              ...        ...              ...       ...
# 1995        10405               76     100.00                3  11739.70
# 1714        10407               76      94.50                6   7182.00
# 2689        10401               77      92.00                9   7084.00
# 2586        10401               85      88.75               10   7543.75
# 418         10405               97      93.28                5   9048.16
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
print("Cách 1")
df[df['SALES']>5000]
# Out:
# Cách 1
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4           10159               49      100.0               14  5205.27
# 7           10188               48      100.0                1  5512.32
# 20          10341               41      100.0                9  7737.93
# 25          10417               66      100.0                2  7516.08
# 26          10103               26      100.0               11  5404.62
# ...           ...              ...        ...              ...      ...
# 2685        10361               44      100.0               10  5001.92
# 2686        10375               44      100.0               11  5208.72
# 2689        10401               77       92.0                9  7084.00
# 2715        10397               48      100.0                3  5192.64
# 2820        10386               43      100.0                4  5417.57
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
print("Cách 2")
df.loc[df['SALES']>5000]
# Out:
# Cách 2
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4           10159               49      100.0               14  5205.27
# 7           10188               48      100.0                1  5512.32
# 20          10341               41      100.0                9  7737.93
# 25          10417               66      100.0                2  7516.08
# 26          10103               26      100.0               11  5404.62
# ...           ...              ...        ...              ...      ...
# 2685        10361               44      100.0               10  5001.92
# 2686        10375               44      100.0               11  5208.72
# 2689        10401               77       92.0                9  7084.00
# 2715        10397               48      100.0                3  5192.64
# 2820        10386               43      100.0                4  5417.57
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
df[(df['SALES']>5000)&(df['QUANTITYORDERED']>40)]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 4           10159               49      100.0               14   5205.27
# 7           10188               48      100.0                1   5512.32
# 20          10341               41      100.0                9   7737.93
# 25          10417               66      100.0                2   7516.08
# 30          10150               45      100.0                8  10993.50
# ...           ...              ...        ...              ...       ...
# 2685        10361               44      100.0               10   5001.92
# 2686        10375               44      100.0               11   5208.72
# 2689        10401               77       92.0                9   7084.00
# 2715        10397               48      100.0                3   5192.64
# 2820        10386               43      100.0                4   5417.57
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
df.loc[df['PRICEEACH']>65,'FLAG']='EXPENSIVE'
df.loc[df['PRICEEACH']<65,'FLAG']='CHEAP'
df[['PRICEEACH','FLAG']][:10]
# Out:
#    PRICEEACH       FLAG
# 0      95.70  EXPENSIVE
# 1      81.35  EXPENSIVE
# 2      94.74  EXPENSIVE
# 3      83.26  EXPENSIVE
# 4     100.00  EXPENSIVE
# 5      96.66  EXPENSIVE
# 6      86.13  EXPENSIVE
# 7     100.00  EXPENSIVE
# 8      98.57  EXPENSIVE
# 9     100.00  EXPENSIVE

# %%
import matplotlib.pyplot as matplotlib
import numpy as np 
import random

# %%
def foo(x):
    if x<10:
        return 'BAD'
    elif x>=10 and x<50:
        return 'GOOD'
    else: 
        return 'EXCELLENT'
df['WORTH']=df[["QUANTITYORDERED"]].applymap(foo)
df[["QUANTITYORDERED",'WORTH']]
# Out:
#       QUANTITYORDERED WORTH
# 0                  30  GOOD
# 1                  34  GOOD
# 2                  41  GOOD
# 3                  45  GOOD
# 4                  49  GOOD
# ...               ...   ...
# 2818               20  GOOD
# 2819               29  GOOD
# 2820               43  GOOD
# 2821               34  GOOD
# 2822               47  GOOD
#
# [2823 rows x 2 columns]

# %%
dict_map1 = {1:'Qui_1',2:'Qui_2',3:'Qui_3',4:'Qui_4'}
df['QTR_ID']=df['QTR_ID'].map(dict_map1)
df['QTR_ID']
# Out:
# 0       Qui_1
# 1       Qui_2
# 2       Qui_3
# 3       Qui_3
# 4       Qui_4
#         ...
# 2818    Qui_4
# 2819    Qui_1
# 2820    Qui_1
# 2821    Qui_1
# 2822    Qui_2
# Name: QTR_ID, Length: 2823, dtype: object

# %%
df[['QUANTITYORDERED','PRICEEACH']].loc[df['YEAR_ID']==2003]
# Out:
#       QUANTITYORDERED  PRICEEACH
# 0                  30      95.70
# 1                  34      81.35
# 2                  41      94.74
# 3                  45      83.26
# 4                  49     100.00
# ...               ...        ...
# 2801               50      60.06
# 2802               38      48.59
# 2803               40      50.23
# 2804               28      64.43
# 2805               42      50.23
#
# [1000 rows x 2 columns]

# %%
df [ df['QUANTITYORDERED']>25]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2817        10337               42      97.16                5  4080.72
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
print("Hiển thị 5 dòng đầu")
a = df [ df['QUANTITYORDERED']>25]
a[:5]
# Out:
# Hiển thị 5 dòng đầu
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %%
dg = df [df ['STATUS']=='Shipped']
df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# ...

# %%
sosanh = df ['STATUS'].str.contains('Shipped')
sosanh.head(5)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: STATUS, dtype: bool

# %%
df['STATUS'].values
# Out:
# array(['Shipped', 'Shipped', 'Shipped', ..., 'Resolved', 'Shipped',
#        'On Hold'], dtype=object)

# %%
import random
df_len = len(df)
ngaylap= [random.randrange(2003,2005,1) for i in range(df_len)]
df['ORDERDATE']= ngaylap
df.tail(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 2818       2003   Shipped       4        12     2004  ...          NaN
# 2819       2004   Shipped       1         1     2005  ...          NaN
# 2820       2003  Resolved       1         3     2005  ...          NaN
# 2821       2003   Shipped       1         3     2005  ...          NaN
# 2822       2003   On Hold       2         5     2005  ...          NaN
#
#           CITY STATE POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %%
df['dagiao']=df['STATUS']=='Shipped'
df.head(5)
